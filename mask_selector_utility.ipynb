# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
from collections import deque
import numpy as np
import argparse
import cv2
import imutils
import time
import matplotlib.pyplot as plt

# %%
image= cv2.imread('Mask_selector.jpg')
# image= cv2.resize(image,(1600,900),interpolation = cv2.INTER_LINEAR)

image_yelow=image[:480,:1000,:]
image_white=image[480:,:1000,:]
image_green= image[:480,1000:,:]
image_red=image[480:,1000:,:]

# %%
image=imutils.resize(image, width=800)

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load image
# image=image_white #image of the object to find the mask for
# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 49 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 7, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 9, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 58, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 2), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 10), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 12), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 14), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 18), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 23), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 26), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 32), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 43), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 49), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 51), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 52), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 79), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 78), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 76), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 60), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 57), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 55), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 53), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 52), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 51), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 50), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 49), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 47), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 46), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 45), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 44), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 43), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 41), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 40), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 38), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 37), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 34), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 35), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 147 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 139 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 137 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 136 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 135 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 133 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 132 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 131 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 129 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 126 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 124 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 122 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 120 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 119 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 118 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 117 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 112 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 105 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 104 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 103 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 101 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 100 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 98 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 100 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 101 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 103 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 105 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 105 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 104 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 103 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 101 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 100 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 254, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 253, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 252, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 251, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 250, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 249, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 248, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 247, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 246, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 245, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 243, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 241, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 237, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 235, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 234, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 233, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 232, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 231, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 230, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 228, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 226, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 225, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 224, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 223, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 224, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 223, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 222, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 223, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 224, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 225, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 226, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 227, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 228, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 230, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 232, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 235, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 238, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 240, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 242, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 243, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 244, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 245, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 246, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 247, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 249, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 250, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 252, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 253, vMax = 255)
# (hMin = 61 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 58 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 54 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 49 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 40, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 39, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 38, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 37, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 36, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 35, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 34, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 33, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 32, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 31, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 30, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 29, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 30, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 31, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 32, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 33, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 34, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 35, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 36, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 37, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 38, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 39, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 42, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 43, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 45, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 47, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 49, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 51, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 52, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 53, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 56, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 58, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 57, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 56, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 55, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 54, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 53, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 52, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 51, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 49, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 48, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 47, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 45, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 44, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 43, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 42, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 40, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 39, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 38, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 39, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 40, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 41, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 42, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 43, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 44, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 45, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 36), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 38), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 39), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 40), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 41), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 42), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 43), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin = 45), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 46, vMin =